# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
file_name = "results_52163"

with open(f"results/{file_name}.json", "r") as fp:
    results = json.load(fp)

print("Ran on:", results["time"])
for key in ["number_of_features", "regularization", "train_acc", "test_acc"]:
    print(f"{key}:", results[key])
# Out:
# Ran on: Friday, 28. November 2025 05:07PM
# number_of_features: 4
# regularization: 1.5
# train_acc: 0.7646484375
# test_acc: 0.5126953125

# %%
y_true = np.array(results["labels_true"])
y_pred = np.array(results["labels_pred"])
(y_true == y_pred).mean()
# Out:
# np.float64(0.5126953125)

# %%
conf_mat = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(conf_mat)
disp.plot()
plt.show()
